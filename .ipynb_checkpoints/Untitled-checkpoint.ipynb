# %%
import pandas as pd
import numpy as np
import scGeneRAI
import os

# %%
#data = pd.read_csv('../GeneNetworkLRP2/data/epi_top2000.csv')

# %%
#sel_data = data[['ID1', 'ID2', 'ID3', 'ID4', 'JUN', 'FOS', 'FOSB', 'HSPA5', 'HSP90B1', 'RPS27', 'RPL10', 'EEF1A1']]

# %%
#sel_data.to_csv('../scGeneRAI/example_data/example_data.csv')

# %%
ex_data = pd.read_csv('../scGeneRAI/example_data/example_data.csv').iloc[:,1:]

# %%
means = ex_data.mean(axis=0)
sds = ex_data.std(axis=0)

ex_data = (ex_data-means)/sds

# %%
model = scGeneRAI.scGeneRAI()

# %%
model.fit(ex_data, nepochs = 100, model_depth =2, early_stopping=False)
# Out:
# 0.000995
# 0 trainloss: tensor(0.4150) testloss: tensor(0.4176)

# %%
model.predict_networks(ex_data.iloc[:50,:], PATH = '.')
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
files = os.listdir('./results')

# %%
network_data = pd.concat([pd.read_csv('./results/' + file) for file in files])

# %%
network_data['LRP'] = np.abs(network_data['LRP'])
network_data = network_data[network_data['source_gene'] != network_data['target_gene']]

average_network = network_data[['LRP', 'source_gene', 'target_gene']].groupby(['source_gene', 'target_gene']).mean()
average_network
# Out:
#                               LRP
# source_gene target_gene
# FOS         EEF1A1       0.053246
# FOSB        EEF1A1       0.063713
#             FOS          0.044970
# HSP90B1     EEF1A1       0.046020
#             FOS          0.029318
# ...                           ...
# RPS27       ID2          0.054613
#             ID3          0.035401
#             ID4          0.055210
#             JUN          0.059900
#             RPL10        0.099176
#
# [66 rows x 1 columns]

# %%
average_network.sort_values(by='LRP', ascending=False).iloc[:30,:]
# Out:
#                               LRP
# source_gene target_gene
# ID4         ID1          0.113745
# RPS27       RPL10        0.099176
# ID4         FOSB         0.078110
# RPL10       ID4          0.077243
# ID4         ID2          0.076775
# RPL10       ID1          0.075497
# JUN         EEF1A1       0.074609
# RPS27       EEF1A1       0.073428
#             HSPA5        0.070129
# RPL10       HSP90B1      0.068603
# FOSB        EEF1A1       0.063713
# RPL10       HSPA5        0.061281
# RPS27       JUN          0.059900
# ID4         HSP90B1      0.057971
# RPS27       ID4          0.055210
#             ID2          0.054613
# FOS         EEF1A1       0.053246
# RPL10       EEF1A1       0.052179
# ID2         HSP90B1      0.051597
# ID4         FOS          0.048664
# ID1         FOSB         0.047822
# RPS27       FOSB         0.047431
# ID4         ID3          0.047056
# RPL10       ID2          0.046126
# HSP90B1     EEF1A1       0.046020
# RPS27       ID1          0.045565
# RPL10       FOS          0.045174
# FOSB        FOS          0.044970
# JUN         ID1          0.044219
#             ID2          0.043252
